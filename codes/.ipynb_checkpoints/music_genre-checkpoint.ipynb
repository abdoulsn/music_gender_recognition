# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
from utils import plot_confusion_matrix
import itertools
import scipy
import numpy as np
import pandas as pd
import soundfile
from PIL import Image
import pathlib
import csv
from scipy import io
from scipy.io import wavfile
from matplotlib.pyplot import specgram
import librosa
import librosa.display
import IPython.display as ipd
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
import os
import glob

# %% [markdown]
# ## Intro
#
# Pour déterminer le genre de musique d'un morceau de musique, un certain nombre de variables basées sur le contenu sont d'abord extraites. En général, les fonctionnalités utilisées pour la classification de la musique peuvent être grossièrement classées en trois classes: la texture timbrale, les caractéristiques rythmiques et les caractéristiques de contenu de hauteur(pitch).
#
# Les caractéristiques du timbre sont généralement caractérisées par les propriétés liées aux instrumentations ou aux sources sonores telles que la musique, la parole ou les signaux d'environnement. Les variables utilisées pour représenter la texture timbrale d'une piste musicale comprennent le zero crossing(le nombre de fois qu'un signal à traversé la barre horizontale à zéro), le centroïde spectral, le flux spectral, spectral rolloff, les coefficients cepstraux de fréquence Mel (MFCCs), etc.

# %% [markdown]
# ### AUDIO FEATURES
# - chroma_stft:
# - spectral_centroid:
# - spectral_bandwidth:
# - rolloff:
# - zero_crossing_rate:
# - rmse:
# - mfcc:

# %% [markdown]
# [stanford docs](http://cs229.stanford.edu/proj2017/final-posters/5142012.pdf)

# %% [markdown]
# ## Chapitre
# 0. Chargement des données
# 1. Exploration
# 2. Extraction des features
# 3. Data processing (red dim, stats desc)
# 4. Application de SVM
# 5. Résultats
# 6. Source of code (if copied)

# %% [markdown]
# ## Construction de la base de données

# %% [markdown]
# Nous allons utiliser l'un des jeux de données les plus connus dasn la reconnaissance de genre musicale, le GTZAN. L'ensemble de données a été développé par [ G. Tzanetakis and P. Cook in IEEE in 2002](http://marsyas.info/downloads/datasets.html) avec des chansons collectées à partir de sources multiples comme les CD et la radio. L'ensemble de données se compose de 1000 fichiers audio bruts au format .wav, d'une durée de 30 secondes chacun.
#
#
#
# L'audio est organisé en 10 genres musicaux, chaque genre avec 100 échantillons. Dans cet ensemble de données, nous avons une fréquence d'échantillonnage de 22050 Hz, un seul canal (mono) et 16 bits pour la quantification. Les genres sont: Metal, Disco, Classique, Hiphop, Jazz, Country, Pop, Blues, Reggae et Rock.

# %%
# Extraction des labels et des noms de fichier puis les enregistrer dans un dictionnaire
genres = []
path_audios = []
dirs = '../data_in/*/*'
for i in glob.glob(dirs):
    if glob.glob(i)[0][-4:] == ".wav":
        path_audios.append(i,)
        genres.append([i][0].split("/")[3].split(".")[0])

# %% [markdown]
# ## EDA

# %%
sample = dict(zip(genres, path_audios))

# %%
import random
_, value = random.choice(list(sample.items()))
print(_)
ipd.Audio(value)
# Out:
# reggae
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
for genre, audio in sample.items():
    plt.figure(figsize=(10,5))
    plt.subplot(3, 1, 1)
    librosa.display.waveplot(librosa.load(audio)[0], alpha=0.5)
    plt.title("forme du wave de "+genre)

# %%
for label, audio in sample.items(): # a revoir
    sample_rate, X = wavfile.read(audio)
    spectro = specgram(X, Fs=sample_rate, xextent=(0,30))

# %% [markdown]
# ## [Features extraction](https://www.ntnu.edu/documents/1001201110/1266017954/DAFx-15_submission_43_v2.pdf)
# Chaque signal audio comprend de nombreuses variables. Cependant, nous devons extraire les variables qui sont pertinentes pour le problème que nous essayons de résoudre. Dans notre cas la reconnaissance du genre musicale.

# %% [markdown]
# initialement: zero_crossing, chroma freq, mfccs, rmse, amplitude envel, spectrale_centroid, spec rollof,

# %% [markdown]
# #### Params fenetrage, deplacement (hope_len), sample rate.

# %%
n_fft = 1024
hop_length = 512

# %% [markdown]
# ### Extraction nuérique à partir des spectro

# %%
file = open('../data_out/rawdata2.csv', 'w', newline='')

# Initialisation des noms de colonnes à extraires
header = 'contrast rmse centroid bandwidth rolloff zero_crossing_rate' # rm filename
for i in range(1, 14): # Pour le mfcc nous en avons 13 on cree 13 noms de colonnes ici
    header += f' mfcc{i}'
header += ' label'
header = header.split()

# initialisation du fichier de données
with file:
    writer = csv.writer(file)
    writer.writerow(header)
genres = 'blues classical country disco hiphop jazz metal pop reggae rock'.split() # les 10 genres de musics

# Extraction des features par boucle
for g in genres:
    for filename in os.listdir(f'../data_in/{g}'):
        songname = f'../data_in/{g}/{filename}'
        y, sr = librosa.load(songname, mono=True) # Données brutes et sampling_rate
        contrast = librosa.feature.spectral_contrast(y, sr=sr)
        rmse = librosa.feature.rms(y, frame_length=n_fft, hop_length=hop_length)
        centroid = librosa.feature.spectral_centroid(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
        bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
        rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
        zcr = librosa.feature.zero_crossing_rate(y, frame_length=n_fft, hop_length=hop_length)
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_fft = n_fft, hop_length = hop_length, n_mfcc=13)
        
        # La moyenne des valeurs sur une fichiers audioos données
        to_append = f'{np.mean(contrast)} {np.mean(rmse)} {np.mean(centroid)} {np.mean(bandwidth)} {np.mean(rolloff)} {np.mean(zcr)}'    
        for e in mfcc:
            to_append += f' {np.mean(e)}'
        to_append += f' {g}'
        file = open('../data_out/rawdata2.csv', 'a', newline='')
        with file:
            writer = csv.writer(file)
            writer.writerow(to_append.split())

# %%
data_path = '../data_out/rawdata2.csv'
raw_feature = pd.read_csv(data_path)
raw_feature.sample(3)
# Out:
#       contrast      rmse     centroid    bandwidth      rolloff  \
# 411  20.674964  0.147418  1906.033063  1885.893969  3671.053079
# 155  20.368483  0.160245  1468.093074  1596.241792  2693.644206
# 138  21.259289  0.021772   971.173317  1101.765951  1677.175061
#
#      zero_crossing_rate       mfcc1       mfcc2      mfcc3      mfcc4  \
# 411            0.101494 -218.719254  101.078979 -29.749958  33.355827
# 155            0.087197 -190.838715  152.747055 -20.684969  16.634111
# 138            0.057943 -435.484344  179.693665 -27.214983   5.996171
#
#         mfcc5      mfcc6      mfcc7      mfcc8      mfcc9     mfcc10  \
# 411 -2.929760  12.741942 -14.730565  14.015551 -15.141988   8.443139
# 155 -1.780287   3.888548  -7.139420  -4.883496  -5.441857   5.381039
# 138 -1.246288 -11.298678 -12.403808 -10.342278 -11.136165 -10.167761
#
#        mfcc11    mfcc12    mfcc13      label
# 411 -4.890142  3.460047 -7.681224     hiphop
# 155 -5.961750 -1.710664 -0.755099  classical
# 138 -7.700024 -9.596363 -5.456679  classical

# %%
import seaborn as sns
sns.scatterplot(x=raw_feature['mfcc1'], y=raw_feature['label'])
# Out:
# <AxesSubplot:xlabel='mfcc1', ylabel='label'>

# %%
sns.scatterplot(x=raw_feature['zero_crossing_rate'], y=raw_feature['label'])
# Out:
# <AxesSubplot:xlabel='zero_crossing_rate', ylabel='label'>

# %%
sns.jointplot(x=raw_feature['rolloff'], y=raw_feature['mfcc3'], kind="kde")

# %% [markdown]
# ### Preparation des données pour le SVM

# %%
from prepare_data import load_data, echantillons
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
X_train, y_train, X_test, y_test = echantillons("../data_out/rawdata.csv", test_size=0.1,)


# X_train = X_train.iloc[:,4:]
# X_test = X_test.iloc[:,4:]
# recodage pour le fit()
y_train = y_train.astype('category')
y_train = y_train.cat.codes
y_test = y_test.astype('category')
y_test = y_test.cat.codes
# Out:
# Échnatillon crées vous avez X et y!
#
#
# Echantillons x_train, y_train, X_validation, y_validation, X_test, y_test crées.

# %%
# Normalisation avec MinMax
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
#Appliqué le meme sur le test aussi
X_test_scaled = scaler.transform(X_test)

# %%
# %matplotlib notebook
# L'importance des variables
clf = RandomForestClassifier(random_state=0, n_jobs=-1).fit(X_train_scaled, y_train)
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
names = [X_train.columns.values[i] for i in indices]
plt.figure()
plt.title("Feature Importance")
plt.bar(range(X_train.shape[1]), importances[indices])
plt.xticks(range(X_train.shape[1]), names, rotation=90)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.5333333333333">

# %% [markdown]
# ### Creation du modele et train du svm et recherche de parametres

# %%
from sklearn.svm import SVC
#import GridSearchCV optimisaion
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

# %%
#intance du modele svc en svm

SVC_M = SVC()
#defiiton du dico des parametres pour l'optimisation
parameters = {"gamma" : [0.0001, 0.001, 0.01, 0.1, 0.4, 1, 1.5, 2, 25],
              "kernel" : ['poly', 'linear'],
              "degree" : [1, 2],
              "C": [0.01, 0.1, 0.4, 1, 10, 20, 50, 100, 200,500]}


scorer = make_scorer(mean_squared_error, greater_is_better=False)
cv = GridSearchCV(SVC_M, parameters, scoring=scorer, n_jobs=-1,cv=5, verbose=1)

cv.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 584 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 1584 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 1777 out of 1800 | elapsed:   14.2s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 1800 out of 1800 | elapsed:   22.1s finished
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 0.4, 1, 10, 20, 50, 100, 200, 500],
#                          'degree': [1, 2],
#                          'gamma': [0.0001, 0.001, 0.01, 0.1, 0.4, 1, 1.5, 2,
#                                    25],
#                          'kernel': ['poly', 'linear']},
#              scoring=make_scorer(mean_squared_error, greater_is_better=False),
#              verbose=1)

# %%
#print le résultats de l'optimisation
def display(results):
    print(f'Meilleurs parameters: {results.best_params_}')
    print("\n")
    mean_score = results.cv_results_['mean_test_score']
    std_score = results.cv_results_['std_test_score']
    params = results.cv_results_['params']
    for mean,std,params in zip(mean_score,std_score,params):
        print(f'{round(mean,3)} + ou -{round(std,3)} pour le {params}')

display(cv)
# Out:
# Meilleurs parameters: {'C': 100, 'degree': 2, 'gamma': 1.5, 'kernel': 'poly'}
#
#
# -21.193 + ou -6.127 pour le {'C': 0.01, 'degree': 1, 'gamma': 0.0001, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 0.01, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 0.01, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 1, 'gamma': 0.01, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 0.01, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 0.01, 'degree': 1, 'gamma': 0.4, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 1, 'gamma': 0.4, 'kernel': 'linear'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# -18.914 + ou -3.489 pour le {'C': 0.01, 'degree': 1, 'gamma': 1.5, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 1, 'gamma': 1.5, 'kernel': 'linear'}
# -15.3 + ou -3.483 pour le {'C': 0.01, 'degree': 1, 'gamma': 2, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 1, 'gamma': 2, 'kernel': 'linear'}
# -12.349 + ou -2.081 pour le {'C': 0.01, 'degree': 1, 'gamma': 25, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 1, 'gamma': 25, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 0.01, 'degree': 2, 'gamma': 0.0001, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 2, 'gamma': 0.0001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 0.01, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 0.01, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 2, 'gamma': 0.01, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 0.01, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# -18.679 + ou -3.282 pour le {'C': 0.01, 'degree': 2, 'gamma': 0.4, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 2, 'gamma': 0.4, 'kernel': 'linear'}
# -12.529 + ou -0.964 pour le {'C': 0.01, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# -13.299 + ou -1.236 pour le {'C': 0.01, 'degree': 2, 'gamma': 1.5, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 2, 'gamma': 1.5, 'kernel': 'linear'}
# -11.928 + ou -1.604 pour le {'C': 0.01, 'degree': 2, 'gamma': 2, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 2, 'gamma': 2, 'kernel': 'linear'}
# -8.241 + ou -1.012 pour le {'C': 0.01, 'degree': 2, 'gamma': 25, 'kernel': 'poly'}
# -19.98 + ou -4.699 pour le {'C': 0.01, 'degree': 2, 'gamma': 25, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 0.1, 'degree': 1, 'gamma': 0.0001, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 0.1, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 1, 'gamma': 0.01, 'kernel': 'linear'}
# -19.98 + ou -4.699 pour le {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# -11.9 + ou -1.894 pour le {'C': 0.1, 'degree': 1, 'gamma': 0.4, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 1, 'gamma': 0.4, 'kernel': 'linear'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# -12.539 + ou -1.413 pour le {'C': 0.1, 'degree': 1, 'gamma': 1.5, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 1, 'gamma': 1.5, 'kernel': 'linear'}
# -12.352 + ou -1.938 pour le {'C': 0.1, 'degree': 1, 'gamma': 2, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 1, 'gamma': 2, 'kernel': 'linear'}
# -10.574 + ou -1.209 pour le {'C': 0.1, 'degree': 1, 'gamma': 25, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 1, 'gamma': 25, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 0.1, 'degree': 2, 'gamma': 0.0001, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 2, 'gamma': 0.0001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 0.1, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 2, 'gamma': 0.01, 'kernel': 'linear'}
# -21.08 + ou -2.933 pour le {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# -13.041 + ou -0.818 pour le {'C': 0.1, 'degree': 2, 'gamma': 0.4, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 2, 'gamma': 0.4, 'kernel': 'linear'}
# -10.887 + ou -1.243 pour le {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# -10.034 + ou -1.53 pour le {'C': 0.1, 'degree': 2, 'gamma': 1.5, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 2, 'gamma': 1.5, 'kernel': 'linear'}
# -9.687 + ou -1.516 pour le {'C': 0.1, 'degree': 2, 'gamma': 2, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 2, 'gamma': 2, 'kernel': 'linear'}
# -8.174 + ou -0.534 pour le {'C': 0.1, 'degree': 2, 'gamma': 25, 'kernel': 'poly'}
# -12.293 + ou -1.27 pour le {'C': 0.1, 'degree': 2, 'gamma': 25, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 0.4, 'degree': 1, 'gamma': 0.0001, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 0.4, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 0.4, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 1, 'gamma': 0.01, 'kernel': 'linear'}
# -11.9 + ou -1.894 pour le {'C': 0.4, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# -12.433 + ou -1.753 pour le {'C': 0.4, 'degree': 1, 'gamma': 0.4, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 1, 'gamma': 0.4, 'kernel': 'linear'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# -11.283 + ou -1.557 pour le {'C': 0.4, 'degree': 1, 'gamma': 1.5, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 1, 'gamma': 1.5, 'kernel': 'linear'}
# -11.488 + ou -1.666 pour le {'C': 0.4, 'degree': 1, 'gamma': 2, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 1, 'gamma': 2, 'kernel': 'linear'}
# -9.862 + ou -0.697 pour le {'C': 0.4, 'degree': 1, 'gamma': 25, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 1, 'gamma': 25, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 0.4, 'degree': 2, 'gamma': 0.0001, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 2, 'gamma': 0.0001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 0.4, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 0.4, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 2, 'gamma': 0.01, 'kernel': 'linear'}
# -12.974 + ou -1.861 pour le {'C': 0.4, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# -11.75 + ou -1.651 pour le {'C': 0.4, 'degree': 2, 'gamma': 0.4, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 2, 'gamma': 0.4, 'kernel': 'linear'}
# -9.687 + ou -1.516 pour le {'C': 0.4, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# -8.873 + ou -0.853 pour le {'C': 0.4, 'degree': 2, 'gamma': 1.5, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 2, 'gamma': 1.5, 'kernel': 'linear'}
# -8.82 + ou -0.87 pour le {'C': 0.4, 'degree': 2, 'gamma': 2, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 2, 'gamma': 2, 'kernel': 'linear'}
# -7.407 + ou -0.749 pour le {'C': 0.4, 'degree': 2, 'gamma': 25, 'kernel': 'poly'}
# -11.813 + ou -1.684 pour le {'C': 0.4, 'degree': 2, 'gamma': 25, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 1, 'degree': 1, 'gamma': 0.0001, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 1, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# -19.98 + ou -4.699 pour le {'C': 1, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 1, 'gamma': 0.01, 'kernel': 'linear'}
# -12.293 + ou -1.27 pour le {'C': 1, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# -11.813 + ou -1.684 pour le {'C': 1, 'degree': 1, 'gamma': 0.4, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 1, 'gamma': 0.4, 'kernel': 'linear'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# -11.002 + ou -1.361 pour le {'C': 1, 'degree': 1, 'gamma': 1.5, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 1, 'gamma': 1.5, 'kernel': 'linear'}
# -10.844 + ou -1.57 pour le {'C': 1, 'degree': 1, 'gamma': 2, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 1, 'gamma': 2, 'kernel': 'linear'}
# -9.302 + ou -0.828 pour le {'C': 1, 'degree': 1, 'gamma': 25, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 1, 'gamma': 25, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 1, 'degree': 2, 'gamma': 0.0001, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 2, 'gamma': 0.0001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 1, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 1, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 2, 'gamma': 0.01, 'kernel': 'linear'}
# -12.529 + ou -0.964 pour le {'C': 1, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# -10.552 + ou -1.941 pour le {'C': 1, 'degree': 2, 'gamma': 0.4, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 2, 'gamma': 0.4, 'kernel': 'linear'}
# -9.286 + ou -0.679 pour le {'C': 1, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# -8.511 + ou -0.839 pour le {'C': 1, 'degree': 2, 'gamma': 1.5, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 2, 'gamma': 1.5, 'kernel': 'linear'}
# -8.642 + ou -0.847 pour le {'C': 1, 'degree': 2, 'gamma': 2, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 2, 'gamma': 2, 'kernel': 'linear'}
# -7.973 + ou -0.493 pour le {'C': 1, 'degree': 2, 'gamma': 25, 'kernel': 'poly'}
# -11.31 + ou -1.73 pour le {'C': 1, 'degree': 2, 'gamma': 25, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 10, 'degree': 1, 'gamma': 0.0001, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# -19.98 + ou -4.699 pour le {'C': 10, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# -12.293 + ou -1.27 pour le {'C': 10, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 1, 'gamma': 0.01, 'kernel': 'linear'}
# -11.31 + ou -1.73 pour le {'C': 10, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# -10.858 + ou -1.71 pour le {'C': 10, 'degree': 1, 'gamma': 0.4, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 1, 'gamma': 0.4, 'kernel': 'linear'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# -9.42 + ou -0.43 pour le {'C': 10, 'degree': 1, 'gamma': 1.5, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 1, 'gamma': 1.5, 'kernel': 'linear'}
# -9.444 + ou -0.762 pour le {'C': 10, 'degree': 1, 'gamma': 2, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 1, 'gamma': 2, 'kernel': 'linear'}
# -8.301 + ou -0.726 pour le {'C': 10, 'degree': 1, 'gamma': 25, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 1, 'gamma': 25, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 10, 'degree': 2, 'gamma': 0.0001, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 2, 'gamma': 0.0001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 10, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# -21.08 + ou -2.933 pour le {'C': 10, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 2, 'gamma': 0.01, 'kernel': 'linear'}
# -10.887 + ou -1.243 pour le {'C': 10, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# -8.82 + ou -0.87 pour le {'C': 10, 'degree': 2, 'gamma': 0.4, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 2, 'gamma': 0.4, 'kernel': 'linear'}
# -8.502 + ou -0.929 pour le {'C': 10, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# -8.198 + ou -1.392 pour le {'C': 10, 'degree': 2, 'gamma': 1.5, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 2, 'gamma': 1.5, 'kernel': 'linear'}
# -8.028 + ou -0.958 pour le {'C': 10, 'degree': 2, 'gamma': 2, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 2, 'gamma': 2, 'kernel': 'linear'}
# -7.607 + ou -0.648 pour le {'C': 10, 'degree': 2, 'gamma': 25, 'kernel': 'poly'}
# -9.852 + ou -0.704 pour le {'C': 10, 'degree': 2, 'gamma': 25, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 20, 'degree': 1, 'gamma': 0.0001, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# -15.3 + ou -3.483 pour le {'C': 20, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# -12.352 + ou -1.938 pour le {'C': 20, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 1, 'gamma': 0.01, 'kernel': 'linear'}
# -10.854 + ou -1.58 pour le {'C': 20, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# -10.263 + ou -0.811 pour le {'C': 20, 'degree': 1, 'gamma': 0.4, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 1, 'gamma': 0.4, 'kernel': 'linear'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# -9.279 + ou -0.767 pour le {'C': 20, 'degree': 1, 'gamma': 1.5, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 1, 'gamma': 1.5, 'kernel': 'linear'}
# -9.041 + ou -0.745 pour le {'C': 20, 'degree': 1, 'gamma': 2, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 1, 'gamma': 2, 'kernel': 'linear'}
# -7.95 + ou -0.511 pour le {'C': 20, 'degree': 1, 'gamma': 25, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 1, 'gamma': 25, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 20, 'degree': 2, 'gamma': 0.0001, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 2, 'gamma': 0.0001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 20, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# -15.491 + ou -2.944 pour le {'C': 20, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 2, 'gamma': 0.01, 'kernel': 'linear'}
# -10.279 + ou -1.514 pour le {'C': 20, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# -8.387 + ou -0.726 pour le {'C': 20, 'degree': 2, 'gamma': 0.4, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 2, 'gamma': 0.4, 'kernel': 'linear'}
# -8.25 + ou -1.268 pour le {'C': 20, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# -7.961 + ou -0.862 pour le {'C': 20, 'degree': 2, 'gamma': 1.5, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 2, 'gamma': 1.5, 'kernel': 'linear'}
# -8.087 + ou -0.691 pour le {'C': 20, 'degree': 2, 'gamma': 2, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 2, 'gamma': 2, 'kernel': 'linear'}
# -7.607 + ou -0.648 pour le {'C': 20, 'degree': 2, 'gamma': 25, 'kernel': 'poly'}
# -9.444 + ou -0.762 pour le {'C': 20, 'degree': 2, 'gamma': 25, 'kernel': 'linear'}
# -21.193 + ou -6.127 pour le {'C': 50, 'degree': 1, 'gamma': 0.0001, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# -11.592 + ou -1.889 pour le {'C': 50, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# -11.611 + ou -1.471 pour le {'C': 50, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 1, 'gamma': 0.01, 'kernel': 'linear'}
# -10.233 + ou -1.436 pour le {'C': 50, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# -9.444 + ou -0.762 pour le {'C': 50, 'degree': 1, 'gamma': 0.4, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 1, 'gamma': 0.4, 'kernel': 'linear'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# -9.172 + ou -1.18 pour le {'C': 50, 'degree': 1, 'gamma': 1.5, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 1, 'gamma': 1.5, 'kernel': 'linear'}
# -9.353 + ou -0.748 pour le {'C': 50, 'degree': 1, 'gamma': 2, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 1, 'gamma': 2, 'kernel': 'linear'}
# -8.157 + ou -0.426 pour le {'C': 50, 'degree': 1, 'gamma': 25, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 1, 'gamma': 25, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 50, 'degree': 2, 'gamma': 0.0001, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 2, 'gamma': 0.0001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 50, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# -12.564 + ou -1.898 pour le {'C': 50, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 2, 'gamma': 0.01, 'kernel': 'linear'}
# -9.426 + ou -1.349 pour le {'C': 50, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# -8.682 + ou -1.015 pour le {'C': 50, 'degree': 2, 'gamma': 0.4, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 2, 'gamma': 0.4, 'kernel': 'linear'}
# -7.911 + ou -0.634 pour le {'C': 50, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# -7.993 + ou -0.562 pour le {'C': 50, 'degree': 2, 'gamma': 1.5, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 2, 'gamma': 1.5, 'kernel': 'linear'}
# -7.624 + ou -0.657 pour le {'C': 50, 'degree': 2, 'gamma': 2, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 2, 'gamma': 2, 'kernel': 'linear'}
# -7.607 + ou -0.648 pour le {'C': 50, 'degree': 2, 'gamma': 25, 'kernel': 'poly'}
# -9.363 + ou -0.9 pour le {'C': 50, 'degree': 2, 'gamma': 25, 'kernel': 'linear'}
# -19.98 + ou -4.699 pour le {'C': 100, 'degree': 1, 'gamma': 0.0001, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# -12.293 + ou -1.27 pour le {'C': 100, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# -11.31 + ou -1.73 pour le {'C': 100, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 1, 'gamma': 0.01, 'kernel': 'linear'}
# -9.852 + ou -0.704 pour le {'C': 100, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# -9.041 + ou -0.745 pour le {'C': 100, 'degree': 1, 'gamma': 0.4, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 1, 'gamma': 0.4, 'kernel': 'linear'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# -8.78 + ou -0.862 pour le {'C': 100, 'degree': 1, 'gamma': 1.5, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 1, 'gamma': 1.5, 'kernel': 'linear'}
# -8.78 + ou -1.055 pour le {'C': 100, 'degree': 1, 'gamma': 2, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 1, 'gamma': 2, 'kernel': 'linear'}
# -8.453 + ou -0.45 pour le {'C': 100, 'degree': 1, 'gamma': 25, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 1, 'gamma': 25, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 100, 'degree': 2, 'gamma': 0.0001, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 2, 'gamma': 0.0001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 100, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# -12.529 + ou -0.964 pour le {'C': 100, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 2, 'gamma': 0.01, 'kernel': 'linear'}
# -9.286 + ou -0.679 pour le {'C': 100, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# -8.359 + ou -0.917 pour le {'C': 100, 'degree': 2, 'gamma': 0.4, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 2, 'gamma': 0.4, 'kernel': 'linear'}
# -8.023 + ou -0.387 pour le {'C': 100, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# -7.403 + ou -0.633 pour le {'C': 100, 'degree': 2, 'gamma': 1.5, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 2, 'gamma': 1.5, 'kernel': 'linear'}
# -7.653 + ou -0.528 pour le {'C': 100, 'degree': 2, 'gamma': 2, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 2, 'gamma': 2, 'kernel': 'linear'}
# -7.607 + ou -0.648 pour le {'C': 100, 'degree': 2, 'gamma': 25, 'kernel': 'poly'}
# -9.353 + ou -0.748 pour le {'C': 100, 'degree': 2, 'gamma': 25, 'kernel': 'linear'}
# -15.3 + ou -3.483 pour le {'C': 200, 'degree': 1, 'gamma': 0.0001, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# -12.352 + ou -1.938 pour le {'C': 200, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# -10.854 + ou -1.58 pour le {'C': 200, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 1, 'gamma': 0.01, 'kernel': 'linear'}
# -9.444 + ou -0.762 pour le {'C': 200, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# -9.206 + ou -0.992 pour le {'C': 200, 'degree': 1, 'gamma': 0.4, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 1, 'gamma': 0.4, 'kernel': 'linear'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# -8.191 + ou -0.44 pour le {'C': 200, 'degree': 1, 'gamma': 1.5, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 1, 'gamma': 1.5, 'kernel': 'linear'}
# -8.083 + ou -0.543 pour le {'C': 200, 'degree': 1, 'gamma': 2, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 1, 'gamma': 2, 'kernel': 'linear'}
# -8.286 + ou -0.365 pour le {'C': 200, 'degree': 1, 'gamma': 25, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 1, 'gamma': 25, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 200, 'degree': 2, 'gamma': 0.0001, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 2, 'gamma': 0.0001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 200, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# -13.469 + ou -0.954 pour le {'C': 200, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 2, 'gamma': 0.01, 'kernel': 'linear'}
# -8.61 + ou -0.792 pour le {'C': 200, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# -7.886 + ou -0.89 pour le {'C': 200, 'degree': 2, 'gamma': 0.4, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 2, 'gamma': 0.4, 'kernel': 'linear'}
# -7.624 + ou -0.657 pour le {'C': 200, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# -7.642 + ou -0.557 pour le {'C': 200, 'degree': 2, 'gamma': 1.5, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 2, 'gamma': 1.5, 'kernel': 'linear'}
# -7.906 + ou -0.496 pour le {'C': 200, 'degree': 2, 'gamma': 2, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 2, 'gamma': 2, 'kernel': 'linear'}
# -7.607 + ou -0.648 pour le {'C': 200, 'degree': 2, 'gamma': 25, 'kernel': 'poly'}
# -8.78 + ou -1.055 pour le {'C': 200, 'degree': 2, 'gamma': 25, 'kernel': 'linear'}
# -11.592 + ou -1.889 pour le {'C': 500, 'degree': 1, 'gamma': 0.0001, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# -11.611 + ou -1.471 pour le {'C': 500, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# -10.233 + ou -1.436 pour le {'C': 500, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 1, 'gamma': 0.01, 'kernel': 'linear'}
# -9.363 + ou -0.9 pour le {'C': 500, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# -8.78 + ou -1.055 pour le {'C': 500, 'degree': 1, 'gamma': 0.4, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 1, 'gamma': 0.4, 'kernel': 'linear'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# -7.947 + ou -0.315 pour le {'C': 500, 'degree': 1, 'gamma': 1.5, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 1, 'gamma': 1.5, 'kernel': 'linear'}
# -8.188 + ou -0.396 pour le {'C': 500, 'degree': 1, 'gamma': 2, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 1, 'gamma': 2, 'kernel': 'linear'}
# -8.34 + ou -0.119 pour le {'C': 500, 'degree': 1, 'gamma': 25, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 1, 'gamma': 25, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 500, 'degree': 2, 'gamma': 0.0001, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 2, 'gamma': 0.0001, 'kernel': 'linear'}
# -22.776 + ou -4.857 pour le {'C': 500, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# -11.444 + ou -1.644 pour le {'C': 500, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 2, 'gamma': 0.01, 'kernel': 'linear'}
# -8.453 + ou -0.773 pour le {'C': 500, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# -8.087 + ou -0.691 pour le {'C': 500, 'degree': 2, 'gamma': 0.4, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 2, 'gamma': 0.4, 'kernel': 'linear'}
# -7.647 + ou -0.502 pour le {'C': 500, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# -7.683 + ou -0.677 pour le {'C': 500, 'degree': 2, 'gamma': 1.5, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 2, 'gamma': 1.5, 'kernel': 'linear'}
# -7.607 + ou -0.648 pour le {'C': 500, 'degree': 2, 'gamma': 2, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 2, 'gamma': 2, 'kernel': 'linear'}
# -7.607 + ou -0.648 pour le {'C': 500, 'degree': 2, 'gamma': 25, 'kernel': 'poly'}
# -7.951 + ou -0.512 pour le {'C': 500, 'degree': 2, 'gamma': 25, 'kernel': 'linear'}

# %% [markdown]
# ### Entrainement avec les parametre optimisé

# %%
#Utilisons ici les params donnés par gridserchcv
grid_svm = SVC(C=100, degree=2, gamma=1.5, kernel='poly') # , C=100, degree=3, gamma=1, kernel='poly'
grid_svm.fit(X_train_scaled, y_train)
y_pred = grid_svm.predict(X_test_scaled)

# plot de la conf matrice
cm = confusion_matrix(y_test, y_pred)
classes = ['metal', 'disco', 'classical', 'hiphop', 'jazz', 'country', 'pop', 'blues', 'reggae', 'rock']
plt.figure(figsize=(10,10))
plot_confusion_matrix(cm, classes, normalize=True)

# %%
from sklearn.metrics import accuracy_score
print("Le score de accuracy est {}%".format(accuracy_score(y_test, y_pred)*100))
# Out:
# Le score de accuracy est 63.0%

# %%
from joblib import dump, load
dump(grid_svm, "../data_out/modeles/grid_svm.joblib")
# Out:
# ['../data_out/modeles/grid_svm.joblib']

# %% [markdown]
# ## Comparaison Modèle réseau de neurones
